# %%
import numpy as np
import torch
from sklearn.manifold import TSNE

import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.cm as cm
import pickle
from collections import defaultdict

# %%
class image_props():
    def __init__(self,tensor,qtype):
        self.feats = tensor
        self.qtypes = [qtype]
    
    def _add_qtype(self,qtype):
        self.qtypes.append(qtype)

# %%
# qtype = "YesNo"
qtypes_list = ["choose", "color", "number", 'shape', "Others", "YesNo"]

qtypes_dict = {}
for i,qtype in enumerate(qtypes_list):
    file = "../../../../data/saved_embed2/{}_image_ids.pkl".format(qtype)
    qtype_index = pickle.load(open(file,'rb'))
    file = "../../../../data/saved_embed2/{}.pt".format(qtype)
    qtype_tensor = torch.load(file)
    print(qtype, qtype_tensor.shape)
    for index,tensor in zip(qtype_index,qtype_tensor):
        if index.item() not in qtypes_dict:
            qtypes_dict[index.item()] = image_props(tensor,qtype)
        else:
            qtypes_dict[index.item()]._add_qtype(qtype)
#     qtypes_dict[qtype] = (i,qtype_tensor)
    
#     for idx in qtype_index:
# #         print(idx.item())
#         qtypes_dict[idx.item()] += 1
    
# #     qtypes_dict[qtype] = (i,qtype_tensor)
# Out:
# choose torch.Size([5730, 2048])
# color torch.Size([2148, 2048])
# number torch.Size([2059, 2048])
# shape torch.Size([623, 2048])
# Others torch.Size([5864, 2048])
# YesNo torch.Size([9616, 2048])

# %%
count = 0
m_count = 0
for qtype in qtypes_dict.keys():
    count += 1
    print(qtypes_dict[qtype].qtypes)
#     print(qtype, qtypes_dict[qtype])
#     if qtypes_dict[qtype] > 1:
# #         print(qtypes_dict[qtype])
#         m_count += 1
print(count, m_count)
# Out:
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'number', 'Others', 'YesNo']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'color', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'Others']
# ['choose']
# ['choose', 'Others']
# ['choose', 'color']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'YesNo']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose', 'number']
# ['choose', 'YesNo']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'color', 'number', 'Others', 'YesNo']
# ['choose']
# ['choose', 'color', 'number']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'number', 'YesNo']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose', 'shape']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'number', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'shape', 'Others']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'color', 'shape', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose', 'number', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose', 'Others']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'color', 'Others']
# ['choose', 'number', 'Others', 'YesNo']
# ['choose', 'color']
# ['choose', 'YesNo']
# ['choose', 'Others', 'YesNo']
# ['choose', 'color', 'YesNo']
# ['choose']
# ['choose', 'number', 'Others']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'color']
# ['choose', 'Others', 'YesNo']
# ['choose', 'YesNo']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'number', 'Others', 'YesNo']
# ['choose', 'Others', 'YesNo']
# ['choose', 'number']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'number', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose', 'number']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'Others']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'color']
# ['choose', 'color', 'number', 'Others']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'color', 'number']
# ['choose']
# ['choose', 'number', 'Others', 'YesNo']
# ['choose']
# ['choose', 'number', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose', 'number']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'number', 'YesNo']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose', 'shape', 'Others']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'color', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'number']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'color', 'Others']
# ['choose']
# ['choose', 'number', 'Others']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'Others']
# ['choose']
# ['choose', 'Others']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'number', 'Others']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose', 'color', 'YesNo']
# ['choose', 'color']
# ['choose', 'color', 'Others']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose', 'shape', 'Others', 'YesNo']
# ['choose', 'color', 'Others', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose', 'color', 'YesNo']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'number']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'number']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'shape', 'Others']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'color', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'number']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose', 'number', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'color']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'number']
# ['choose', 'Others']
# ['choose', 'Others']
# ['choose']
# ['choose', 'color']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'number', 'YesNo']
# ['choose']
# ['choose', 'color']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'shape', 'YesNo']
# ['choose']
# ['choose', 'shape', 'YesNo']
# ['choose', 'shape']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose', 'Others']
# ['choose']
# ['choose', 'color']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'color', 'Others', 'YesNo']
# ['choose']
# ['choose', 'color', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'Others', 'YesNo']
# ['choose', 'Others', 'YesNo']
# ['choose', 'YesNo']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'color', 'Others']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'color', 'shape']
# ['choose', 'Others']
# ['choose']
# ['choose', 'number']
# ['choose', 'Others']
# ['choose']
# ['choose', 'color', 'Others']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose', 'color', 'Others']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'number']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'number', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'Others']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose', 'color']
# ['choose', 'number', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'number', 'YesNo']
# ['choose']
# ['choose', 'number']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'color', 'number']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'number', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'number']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose', 'color', 'Others']
# ['choose']
# ['choose']
# ['choose', 'number']
# ['choose', 'YesNo']
# ['choose', 'Others']
# ['choose', 'color', 'Others']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'Others']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose', 'number']
# ['choose', 'shape', 'Others', 'YesNo']
# ['choose', 'color', 'Others']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'number', 'YesNo']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'color']
# ['choose', 'color', 'Others']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'Others']
# ['choose', 'Others', 'YesNo']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose', 'number']
# ['choose', 'shape']
# ['choose', 'number', 'YesNo']
# ['choose', 'color', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose', 'color', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'color']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'color', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'color']
# ['choose', 'Others']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'Others']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose', 'color', 'number']
# ['choose', 'shape', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose', 'YesNo']
# ['choose', 'YesNo']
# ['choose', 'number']
# ['choose', 'number', 'Others']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose', 'number', 'Others', 'YesNo']
# ['choose']
# ['choose', 'Others']
# ['choose', 'Others', 'YesNo']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'color']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'Others']
# ['choose', 'color', 'number', 'YesNo']
# ['choose', 'YesNo']
# ['choose', 'shape', 'Others']
# ['choose', 'number', 'YesNo']
# ['choose', 'Others']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'shape']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose', 'number', 'Others', 'YesNo']
# ['choose', 'shape']
# ['choose', 'Others', 'YesNo']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'number', 'Others', 'YesNo']
# ['choose', 'YesNo']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'color', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'number']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'number']
# ['choose']
# ['choose', 'number', 'YesNo']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'number', 'shape', 'Others']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose', 'number']
# ['choose', 'Others', 'YesNo']
# ['choose', 'color', 'Others']
# ['choose', 'number', 'shape', 'YesNo']
# ['choose', 'YesNo']
# ['choose', 'YesNo']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'color', 'Others', 'YesNo']
# ['choose', 'color']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'color']
# ['choose', 'color', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose', 'color', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'number']
# ['choose']
# ['choose']
# ['choose', 'number']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'shape', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'YesNo']
# ['choose', 'Others']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'number']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose', 'number', 'Others', 'YesNo']
# ['choose', 'Others']
# ['choose', 'color', 'Others']
# ['choose', 'YesNo']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'number', 'Others']
# ['choose', 'shape']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'color', 'Others']
# ['choose']
# ['choose', 'number', 'Others', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'Others']
# ['choose', 'YesNo']
# ['choose', 'YesNo']
# ['choose', 'YesNo']
# ['choose', 'number', 'YesNo']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose', 'number', 'shape']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'number', 'YesNo']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'shape', 'Others', 'YesNo']
# ['choose']
# ['choose', 'Others']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'number']
# ['choose']
# ['choose']
# ['choose', 'shape', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'color']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'shape', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'color', 'Others']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'color', 'Others']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'color']
# ['choose', 'color', 'Others']
# ['choose', 'color', 'YesNo']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'number', 'shape', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'color']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'number']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose', 'number', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'number']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'color']
# ['choose', 'number']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'color', 'shape', 'Others', 'YesNo']
# ['choose', 'color', 'number', 'Others', 'YesNo']
# ['choose']
# ['choose', 'color']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'number', 'Others', 'YesNo']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'number']
# ['choose', 'number']
# ['choose', 'YesNo']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'color']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose', 'color']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'color', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'number', 'Others']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'Others', 'YesNo']
# ['choose', 'YesNo']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'color', 'number', 'Others']
# ['choose', 'number']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'color']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'color', 'number', 'Others', 'YesNo']
# ['choose', 'number', 'Others']
# ['choose', 'color']
# ['choose', 'number']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'color', 'YesNo']
# ['choose', 'Others']
# ['choose']
# ['choose', 'color', 'Others', 'YesNo']
# ['choose', 'shape']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'shape', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'number']
# ['choose']
# ['choose', 'number']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'number', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'color', 'Others', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'number', 'Others']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'color', 'YesNo']
# ['choose', 'Others']
# ['choose', 'Others']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'YesNo']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'color']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'Others', 'YesNo']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'color', 'Others', 'YesNo']
# ['choose']
# ['choose', 'color', 'number']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'number', 'Others']
# ['choose']
# ['choose', 'color', 'shape', 'Others', 'YesNo']
# ['choose', 'YesNo']
# ['choose', 'number', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'color', 'YesNo']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'color']
# ['choose', 'Others']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'number', 'YesNo']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose', 'Others', 'YesNo']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose', 'color', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'color']
# ['choose']
# ['choose', 'shape', 'Others']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'color', 'number']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'color']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'shape', 'YesNo']
# ['choose', 'Others', 'YesNo']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'shape', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'number', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'color', 'YesNo']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'color']
# ['choose', 'YesNo']
# ['choose', 'number', 'Others', 'YesNo']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose', 'color']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'YesNo']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'color', 'shape', 'Others']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'color']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose', 'Others']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose', 'number', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose', 'color', 'YesNo']
# ['choose', 'color', 'number', 'YesNo']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose', 'number']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose', 'YesNo']
# ['choose', 'number', 'YesNo']
# ['choose', 'YesNo']
# ['choose', 'number']
# ['choose']
# ['choose', 'number', 'YesNo']
# ['choose']
# ['choose', 'number', 'Others']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'color', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose', 'Others']
# ['choose', 'number', 'Others', 'YesNo']
# ['choose', 'YesNo']
# ['choose', 'Others']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'YesNo']
# ['choose', 'number', 'YesNo']
# ['choose', 'color', 'Others']
# ['choose']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'color', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'number']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'Others', 'YesNo']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'shape', 'Others']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'color', 'YesNo']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'Others']
# ['choose', 'Others']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'number']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'color', 'number', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'shape']
# ['choose', 'Others']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose', 'number']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'Others']
# ['choose', 'number']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'number', 'shape', 'Others', 'YesNo']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'color']
# ['choose', 'YesNo']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'Others']
# ['choose', 'Others', 'YesNo']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose', 'color', 'Others']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'shape', 'YesNo']
# ['choose', 'Others']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'YesNo']
# ['choose', 'number']
# ['choose', 'Others']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'Others']
# ['choose', 'shape', 'YesNo']
# ['choose', 'YesNo']
# ['choose', 'color', 'number', 'Others']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose', 'color']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose', 'Others']
# ['choose', 'shape']
# ['choose', 'Others']
# ['choose', 'YesNo']
# ['choose', 'number', 'Others']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'color', 'shape', 'YesNo']
# ['choose', 'Others']
# ['choose', 'Others']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose', 'color']
# ['choose', 'color', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose', 'Others']
# ['choose', 'shape', 'Others']
# ['choose', 'shape']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose', 'number']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'color']
# ['choose']
# ['choose', 'number', 'Others']
# ['choose']
# ['choose']
# ['choose', 'color']
# ['choose', 'number', 'Others']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'color', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'color']
# ['choose']
# ['choose', 'Others']
# ['choose', 'number', 'Others']
# ['choose']
# ['choose', 'number', 'Others']
# ['choose', 'color']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'color']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'color']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'color', 'shape']
# ['choose', 'YesNo']
# ['choose', 'YesNo']
# ['choose', 'color', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'number', 'Others']
# ['choose']
# ['choose', 'shape']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose', 'color']
# ['choose']
# ['choose', 'color', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'Others']
# ['choose']
# ['choose', 'color', 'YesNo']
# ['choose', 'Others', 'YesNo']
# ['choose', 'YesNo']
# ['choose', 'Others']
# ['choose', 'Others']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose', 'color']
# ['choose', 'number', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'number', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'color', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'number', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'color', 'number']
# ['choose', 'Others']
# ['choose']
# ['choose', 'number']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'number']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'number', 'shape', 'Others', 'YesNo']
# ['choose']
# ['choose', 'color', 'Others']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose', 'Others']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'Others']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose', 'Others']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose', 'color']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'number', 'Others']
# ['choose']
# ['choose', 'number', 'Others', 'YesNo']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'color', 'YesNo']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose', 'color', 'Others', 'YesNo']
# ['choose', 'number']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose', 'Others']
# ['choose', 'Others']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'YesNo']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'color', 'number', 'Others', 'YesNo']
# ['choose', 'number']
# ['choose']
# ['choose', 'number']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'number']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'Others']
# ['choose', 'YesNo']
# ['choose', 'number']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'color']
# ['choose', 'number']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'shape', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose', 'number']
# ['choose']
# ['choose', 'color']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'shape', 'YesNo']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose', 'Others', 'YesNo']
# ['choose', 'Others']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose', 'color']
# ['choose', 'shape', 'Others', 'YesNo']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose', 'color']
# ['choose', 'Others', 'YesNo']
# ['choose', 'YesNo']
# ['choose', 'number']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'number', 'shape', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'color', 'number', 'Others', 'YesNo']
# ['choose', 'Others', 'YesNo']
# ['choose', 'YesNo']
# ['choose', 'number']
# ['choose', 'color']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'color', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'number', 'Others']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'color', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose', 'color']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'color']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'color', 'YesNo']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose', 'number', 'YesNo']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose', 'number']
# ['choose']
# ['choose']
# ['choose', 'color']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'number']
# ['choose']
# ['choose']
# ['choose', 'number', 'Others']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'shape']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'YesNo']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'color']
# ['choose', 'number']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose', 'number', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'number', 'YesNo']
# ['choose']
# ['choose', 'number']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose', 'number']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'color']
# ['choose']
# ['choose', 'color']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'color']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'number', 'Others', 'YesNo']
# ['choose']
# ['choose', 'number', 'Others']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'color']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'number', 'YesNo']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose', 'color']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'shape', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'color', 'number', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose', 'number']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'Others', 'YesNo']
# ['choose', 'YesNo']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'color', 'number', 'Others', 'YesNo']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'color']
# ['choose', 'Others']
# ['choose', 'Others']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'Others']
# ['choose', 'number', 'YesNo']
# ['choose']
# ['choose', 'Others']
# ['choose', 'color', 'number', 'YesNo']
# ['choose']
# ['choose', 'number', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose', 'number', 'Others']
# ['choose']
# ['choose', 'shape']
# ['choose']
# ['choose', 'number']
# ['choose']
# ['choose', 'number', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'color', 'Others']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose', 'number', 'Others']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'number']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'number', 'Others', 'YesNo']
# ['choose', 'number']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'number', 'Others', 'YesNo']
# ['choose', 'shape']
# ['choose', 'number']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'color', 'Others', 'YesNo']
# ['choose', 'color', 'YesNo']
# ['choose']
# ['choose', 'Others']
# ['choose', 'number', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'number', 'Others']
# ['choose']
# ['choose']
# ['choose', 'color']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'number', 'shape', 'YesNo']
# ['choose']
# ['choose', 'Others']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'shape', 'YesNo']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose', 'color', 'shape', 'Others', 'YesNo']
# ['choose']
# ['choose', 'color']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'shape']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'number']
# ['choose', 'shape']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'color', 'Others', 'YesNo']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'number']
# ['choose', 'YesNo']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'number']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'shape', 'Others', 'YesNo']
# ['choose', 'YesNo']
# ['choose', 'color']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'number', 'Others']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'color', 'Others', 'YesNo']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'color', 'YesNo']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'number', 'Others']
# ['choose', 'YesNo']
# ['choose', 'number']
# ['choose', 'color', 'Others']
# ['choose']
# ['choose', 'number']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose', 'number']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'color']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'shape']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose', 'Others']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose', 'color', 'YesNo']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'color', 'Others', 'YesNo']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'number', 'YesNo']
# ['choose', 'number', 'Others', 'YesNo']
# ['choose', 'number']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose', 'color', 'number', 'Others']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'color', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'color', 'Others']
# ['choose', 'Others']
# ['choose', 'YesNo']
# ['choose', 'number', 'Others', 'YesNo']
# ['choose', 'color', 'number', 'Others', 'YesNo']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'Others']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'color', 'number', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'Others']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'number']
# ['choose']
# ['choose', 'color', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose', 'number', 'Others']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'shape', 'Others']
# ['choose']
# ['choose', 'number', 'Others', 'YesNo']
# ['choose', 'YesNo']
# ['choose', 'Others']
# ['choose']
# ['choose', 'color', 'Others']
# ['choose']
# ['choose']
# ['choose', 'color']
# ['choose']
# ['choose', 'Others']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose', 'number', 'YesNo']
# ['choose', 'Others']
# ['choose', 'color']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'shape', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'color']
# ['choose', 'Others']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'Others']
# ['choose', 'Others']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose', 'color', 'number', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'Others']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose', 'Others']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'color', 'Others']
# ['choose', 'Others']
# ['choose']
# ['choose', 'Others']
# ['choose', 'Others']
# ['choose']
# ['choose', 'Others']
# ['choose', 'YesNo']
# ['choose', 'number', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'color', 'number', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'color', 'number', 'YesNo']
# ['choose', 'number']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'color']
# ['choose']
# ['choose']
# ['choose', 'shape', 'Others', 'YesNo']
# ['choose', 'number', 'Others']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'shape', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose', 'Others']
# ['choose', 'Others']
# ['choose', 'Others']
# ['choose']
# ['choose', 'number', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'number']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'number']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'number', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'number', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'shape']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'color']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'number']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose', 'number', 'Others']
# ['choose', 'number']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'number']
# ['choose']
# ['choose', 'color']
# ['choose']
# ['choose', 'Others']
# ['choose', 'Others']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose', 'number', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'YesNo']
# ['choose', 'Others']
# ['choose']
# ['choose', 'color', 'number', 'YesNo']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'number', 'Others']
# ['choose', 'Others']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'number', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'number', 'YesNo']
# ['choose', 'Others']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'color']
# ['choose', 'Others']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose', 'color', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'number', 'YesNo']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'number']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'color']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose', 'number', 'Others', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'number', 'Others', 'YesNo']
# ['choose', 'number']
# ['choose', 'color', 'Others']
# ['choose']
# ['choose', 'Others']
# ['choose', 'color', 'YesNo']
# ['choose']
# ['choose']
# ['choose', 'Others']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'color']
# ['choose', 'color', 'YesNo']
# ['choose']
# ['choose', 'color', 'Others']
# ['choose', 'YesNo']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'Others']
# ['choose', 'number', 'Others']
# ['choose']
# ['choose', 'color']
# ['choose']
# ['choose', 'YesNo']
# ['choose', 'shape']
# ['choose', 'YesNo']
# ['choose', 'YesNo']
# ['choose']
# ['choose']
# ['choose']
# ['choose', 'YesNo']
# ...
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# ['YesNo']
# 19960 0

# %%
color_each_class = cm.rainbow(np.linspace(0,1,6))
color_class_lookup = {}
for i in range(len(color_each_class)):
    color_class_lookup[qtypes_list[i]] = color_each_class[i]

# %%
qtypes_list = ["choose", "color", "number", "Others", "YesNo"]

qtypes_dict = {}
for i,qtype in enumerate(qtypes_list):
    file = "../../../../data/saved_embed/{}.pt".format(qtype)
#     qtype_feat = pickle.load(open(file,'rb'))
#     file = "../../../../data/saved_embed/{}.pt".format(qtype)
    qtype_tensor = torch.load(file)
    qtype_dict[qtype] = qtype_tensor
#     print(qtype, qtype_tensor.shape)
#     for index,tensor in zip(qtype_index,qtype_tensor):
#         if index.item() not in qtypes_dict:
#             qtypes_dict[index.item()] = image_props(tensor,qtype)
#         else:
#             qtypes_dict[index.item()]._add_qtype(qtype)

r_idx = torch.randint(high=2000,size=(1000,))

qtype_feats = None
qtype_labels = None
for qtype in qtypes_dict.keys():
    if qtype_feats is None:
        i,qtype_feats = qtypes_dict[qtype]
        qtype_feats = qtype_feats[r_idx]
        qtype_labels = torch.tensor(color_each_class[i]).unsqueeze(0).repeat(qtype_feats.shape[0],1)
    else:
        i,qtype_feat = qtypes_dict[qtype]
        qtype_feat = qtype_feat[r_idx]
        qtype_feats = torch.cat((qtype_feats,qtype_feat))
        print(color_each_class[i])
        qtype_labels = torch.cat((qtype_labels,torch.tensor(color_each_class[i]).unsqueeze(0).repeat(qtype_feat.shape[0],1)))
print(qtype_feats.shape)
print(qtype_labels.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4622/2429515808.py in <module>
#       1 qtypes_list = ["choose", "color", "number", "Others", "YesNo"]
#       2
# ----> 3 qtypes_dict = default_dict()
#       4 for i,qtype in enumerate(qtypes_list):
#       5     file = "../../../../data/saved_embed/{}.pt".format(qtype)
#
# NameError: name 'default_dict' is not defined

# %%
tsne = TSNE(n_components=2,n_iter=6000,n_jobs=-1,init='pca',perplexity=100)



qtype_features = np.asarray(qtype_feats, dtype='float64')

qtype_tsne = tsne.fit_transform(qtype_features)
# Out:
# /home/ubuntu/anaconda3/envs/mmmlx/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# /home/ubuntu/anaconda3/envs/mmmlx/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:982: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   warnings.warn(

# %%
# fig = plt.figure()
# ax = fig.add_subplot(projection='3d')
color_each_class = cm.rainbow(np.linspace(0,1,6))
cell_text = None
for i,qtype in enumerate(qtypes_dict.keys()):
    if cell_text is None:
        cell_text = np.expand_dims(["",qtypes_list[qtypes_dict[qtype][0]]],axis=0)
    else:
        cell_text = np.concatenate((cell_text,np.expand_dims(["",qtypes_list[qtypes_dict[qtype][0]]],axis=0)),axis=0)
legend = plt.table(cellText=cell_text,colWidths=[0.05,0.12],cellLoc='right',loc='best')
for i,qtype in enumerate(qtypes_dict.keys()):
    legend[(i,0)].set_facecolor(color_each_class[qtypes_dict[qtype][0]])
plt.rcParams["figure.figsize"] = (15,10)

plt.scatter(qtype_tsne[:,0],qtype_tsne[:,1],c=qtype_labels)

# %%
qtype_feats = None
qtype_labels = None

for image_idx in qtypes_dict.keys():
    if qtype_feats is None:
        qtype_feats = qtypes_dict[image_idx].feats.unsqueeze(0)

        qtypes_in_image = qtypes_dict[image_idx].qtypes
        qtype_labels = np.zeros((1,4))
        for q in qtypes_in_image:
            qtype_labels += color_class_lookup[q]
        qtype_labels /= len(qtypes_in_image)

    else:
        qtype_feat = qtypes_dict[image_idx].feats.unsqueeze(0)

        qtypes_in_image = qtypes_dict[image_idx].qtypes
        qtype_label = np.zeros((1,4))
        for q in qtypes_in_image:
            qtype_label += color_class_lookup[q]
        qtype_label /= len(qtypes_in_image)
        
        
        qtype_feats = torch.cat((qtype_feats,qtype_feat),dim=0)
        qtype_labels = np.concatenate((qtype_labels,qtype_label),axis=0)
print(qtype_feats.shape)
print(qtype_labels.shape)
# Out:
# torch.Size([19960, 2048])
# (19960, 4)

# %%
tsne = TSNE(n_components=2,n_iter=3000,n_jobs=-1,init='pca',perplexity=30)



qtype_features = np.asarray(qtype_feats, dtype='float64')

qtype_tsne = tsne.fit_transform(qtype_features)
# Out:
# /home/ubuntu/anaconda3/envs/mmmlx/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# /home/ubuntu/anaconda3/envs/mmmlx/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:982: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   warnings.warn(

# %%
cell_text = None
for i,qtype in enumerate(qtypes_list):
    if cell_text is None:
        cell_text = np.expand_dims(["",qtype],axis=0)
    else:
        cell_text = np.concatenate((cell_text,np.expand_dims(["",qtype],axis=0)),axis=0)
legend = plt.table(cellText=cell_text,colWidths=[0.05,0.12],cellLoc='right',loc='best')

for i,qtype in enumerate(qtypes_list):
    legend[(i,0)].set_facecolor(color_class_lookup[qtype])


plt.rcParams["figure.figsize"] = (15,10)
plt.scatter(qtype_tsne[:,0],qtype_tsne[:,1],c=qtype_labels)
